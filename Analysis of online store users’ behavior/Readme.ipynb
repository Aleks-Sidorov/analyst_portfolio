# %% [markdown]
# ### **[открыть в IPYNB](https://github.com/Aleks-Sidorov/analyst_portfolio/blob/main/Analysis%20of%20online%20store%20users’%20behavior/Анализ%20поведения%20пользователей%20интернет-магазина.ipynb)**
# ### **[открыть в PDF](https://github.com/Aleks-Sidorov/analyst_portfolio/blob/main/Analysis%20of%20online%20store%20users’%20behavior/Анализ%20поведения%20пользователей%20интернет-магазина.pdf)**
# ### **[открыть в HTML](https://htmlpreview.github.io/?https://github.com/Aleks-Sidorov/analyst_portfolio/blob/main/Analysis%20of%20online%20store%20users’%20behavior/Analysis%20of%20online%20store%20users’%20behavior.html)**
#
# ## О проекте
#
# Анализ поведения пользователей в интернет-магазине электроники.
#
# **Цель**: понять, на каком этапе воронки магазин теряет пользователей, оценить удержание по когортам.
#
# ---
#
# ### Инструменты
#
# **Python**
#
# - `Pandas`
# - `Matplotlib`
# - `seaborn`
#
# **Источник данных:** [Kaggle](https://www.kaggle.com/datasets/mkechinov/ecommerce-events-history-in-electronics-store)
#
# ---
